# %%
import pandas as pd

# %%
import pandas as pd

data = [10, 20, 30, 40]
s = pd.Series(data)

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([10, 20, 30], index=["a", "b", "c"])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print(s["a"])
# Out:
# 10

# %%
data = {"A": 50, "B": 60, "C": 70}
s = pd.Series(data)

print(s)
# Out:
# A    50
# B    60
# C    70
# dtype: int64

# %%
import pandas as pd

data = {
    "Name": ["Riya", "Aman", "Priya"],
    "Age": [21, 22, 20]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0   Riya   21
# 1   Aman   22
# 2  Priya   20

# %%
df = pd.read_csv("people-1000.csv")
df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title
# 0         Probation officer
# 1                    Dancer
# 2                      Copy
# 3  Counselling psychologist
# 4       Biomedical engineer

# %%
df.tail()
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                        Email                  Phone Date of birth  \
# 995   lyonsdaisy@example.net           021.775.2933    1959-01-05
# 996  dariusbryan@example.com   001-149-710-7799x721    2001-10-06
# 997   georgechan@example.org  +1-750-774-4128x33265    1918-05-13
# 998      wanda04@example.net          (915)292-2254    1971-08-31
# 999  deannablack@example.org     079.752.5424x67259    1947-01-24
#
#                            Job Title
# 995                Personnel officer
# 996          Education administrator
# 997  Commercial/residential surveyor
# 998                 Ambulance person
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Sex            1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          1000 non-null   object
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#              Index
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df["First Name"]
# Out:
# 0        Shelia
# 1            Jo
# 2        Sheryl
# 3       Whitney
# 4       Lindsey
#          ...
# 995        Kurt
# 996       Donna
# 997       Cathy
# 998    Jermaine
# 999         Lee
# Name: First Name, Length: 1000, dtype: object

# %%
f=pd.read_csv("Match_Info.csv")
df=pd.DataFrame(f)
df
# Out:
#       match_number                        team1                        team2  \
# 0           336036             Rajasthan Royals               Mumbai Indians
# 1           335995              Kings XI Punjab             Delhi Daredevils
# 2          1254108  Royal Challengers Bangalore               Mumbai Indians
# 3           829761        Kolkata Knight Riders             Delhi Daredevils
# 4          1216521          Chennai Super Kings               Mumbai Indians
# ...            ...                          ...                          ...
# 1164        336017        Kolkata Knight Riders             Delhi Daredevils
# 1165        981007                Gujarat Lions               Mumbai Indians
# 1166        980931      Rising Pune Supergiants  Royal Challengers Bangalore
# 1167       1304095  Royal Challengers Bangalore          Chennai Super Kings
# 1168       1136568              Kings XI Punjab  Royal Challengers Bangalore
#
# ...

# %%
df.shape
# Out:
# (1169, 14)

# %%
df.shape[0]
# Out:
# 1169

# %%
df.size
# Out:
# 16366

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_number     1169 non-null   int64
#  1   team1            1169 non-null   object
#  2   team2            1169 non-null   object
#  3   match_date       1169 non-null   object
#  4   toss_winner      1169 non-null   object
#  5   toss_decision    1169 non-null   object
#  6   result           1169 non-null   object
#  7   eliminator       15 non-null     object
#  8   winner           1146 non-null   object
#  9   player_of_match  1169 non-null   object
#  10  venue            1169 non-null   object
#  11  city             1118 non-null   object
#  12  team1_players    1169 non-null   object
#  13  team2_players    1169 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 128.0+ KB

# %%
df.columns
# Out:
# Index(['match_number', 'team1', 'team2', 'match_date', 'toss_winner',
#        'toss_decision', 'result', 'eliminator', 'winner', 'player_of_match',
#        'venue', 'city', 'team1_players', 'team2_players'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# match_number        int64
# team1              object
# team2              object
# match_date         object
# toss_winner        object
# toss_decision      object
# result             object
# eliminator         object
# winner             object
# player_of_match    object
# venue              object
# city               object
# team1_players      object
# team2_players      object
# dtype: object

# %%
df.size
# Out:
# 16366

# %%
df.columns
# Out:
# Index(['match_number', 'team1', 'team2', 'match_date', 'toss_winner',
#        'toss_decision', 'result', 'eliminator', 'winner', 'player_of_match',
#        'venue', 'city', 'team1_players', 'team2_players'],
#       dtype='object')

# %%
df["winner"]
# Out:
# 0                  Rajasthan Royals
# 1                   Kings XI Punjab
# 2       Royal Challengers Bangalore
# 3             Kolkata Knight Riders
# 4                    Mumbai Indians
#                    ...
# 1164          Kolkata Knight Riders
# 1165                  Gujarat Lions
# 1166    Royal Challengers Bangalore
# 1167    Royal Challengers Bangalore
# 1168    Royal Challengers Bangalore
# Name: winner, Length: 1169, dtype: object

# %%
df[["winner","player_of_match"]]
# Out:
#                            winner player_of_match
# 0                Rajasthan Royals   Sohail Tanvir
# 1                 Kings XI Punjab       SM Katich
# 2     Royal Challengers Bangalore      GJ Maxwell
# 3           Kolkata Knight Riders       PP Chawla
# 4                  Mumbai Indians        TA Boult
# ...                           ...             ...
# 1164        Kolkata Knight Riders   Shoaib Akhtar
# 1165                Gujarat Lions        SK Raina
# 1166  Royal Challengers Bangalore  AB de Villiers
# 1167  Royal Challengers Bangalore        HV Patel
# 1168  Royal Challengers Bangalore        UT Yadav
#
# [1169 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# match_number                                                  336036
# team1                                               Rajasthan Royals
# team2                                                 Mumbai Indians
# match_date                                                2008-05-26
# toss_winner                                         Rajasthan Royals
# toss_decision                                                  field
# result                                                           Win
# eliminator                                                       NaN
# winner                                              Rajasthan Royals
# player_of_match                                        Sohail Tanvir
# venue                                         Sawai Mansingh Stadium
# city                                                          Jaipur
# team1_players      Kamran Akmal, SA Asnodkar, YK Pathan, SR Watso...
# team2_players      ST Jayasuriya, SR Tendulkar, AM Nayar, RV Utha...
# ...

# %%
df.iloc[0:5]
# Out:
#    match_number                        team1             team2  match_date  \
# 0        336036             Rajasthan Royals    Mumbai Indians  2008-05-26
# 1        335995              Kings XI Punjab  Delhi Daredevils  2008-04-27
# 2       1254108  Royal Challengers Bangalore    Mumbai Indians  2021-09-26
# 3        829761        Kolkata Knight Riders  Delhi Daredevils  2015-05-07
# 4       1216521          Chennai Super Kings    Mumbai Indians  2020-10-23
#
#              toss_winner toss_decision result eliminator  \
# 0       Rajasthan Royals         field    Win        NaN
# 1       Delhi Daredevils           bat    Win        NaN
# 2         Mumbai Indians         field    Win        NaN
# 3  Kolkata Knight Riders           bat    Win        NaN
# 4         Mumbai Indians         field    Win        NaN
#
#                         winner player_of_match  \
# 0             Rajasthan Royals   Sohail Tanvir
# 1              Kings XI Punjab       SM Katich
# ...

# %%
df.iloc[0:5,0:5]
# Out:
#    match_number                        team1             team2  match_date  \
# 0        336036             Rajasthan Royals    Mumbai Indians  2008-05-26
# 1        335995              Kings XI Punjab  Delhi Daredevils  2008-04-27
# 2       1254108  Royal Challengers Bangalore    Mumbai Indians  2021-09-26
# 3        829761        Kolkata Knight Riders  Delhi Daredevils  2015-05-07
# 4       1216521          Chennai Super Kings    Mumbai Indians  2020-10-23
#
#              toss_winner
# 0       Rajasthan Royals
# 1       Delhi Daredevils
# 2         Mumbai Indians
# 3  Kolkata Knight Riders
# 4         Mumbai Indians

# %%
df.loc[0:3,"match_number":"result"]
# Out:
#    match_number                        team1             team2  match_date  \
# 0        336036             Rajasthan Royals    Mumbai Indians  2008-05-26
# 1        335995              Kings XI Punjab  Delhi Daredevils  2008-04-27
# 2       1254108  Royal Challengers Bangalore    Mumbai Indians  2021-09-26
# 3        829761        Kolkata Knight Riders  Delhi Daredevils  2015-05-07
#
#              toss_winner toss_decision result
# 0       Rajasthan Royals         field    Win
# 1       Delhi Daredevils           bat    Win
# 2         Mumbai Indians         field    Win
# 3  Kolkata Knight Riders           bat    Win

# %%
df[df["city"]=="Ahmedabad"][["team1","team2"]]
# Out:
#                             team1                        team2
# 44                   Punjab Kings               Delhi Capitals
# 72               Rajasthan Royals               Mumbai Indians
# 96                 Gujarat Titans             Rajasthan Royals
# 118                Gujarat Titans          Chennai Super Kings
# 139                Gujarat Titans               Mumbai Indians
# 149                Gujarat Titans               Mumbai Indians
# 164                Gujarat Titans         Lucknow Super Giants
# 173              Rajasthan Royals          Sunrisers Hyderabad
# 215                Gujarat Titans                 Punjab Kings
# 272              Rajasthan Royals               Gujarat Titans
# 323              Rajasthan Royals        Kolkata Knight Riders
# 334              Rajasthan Royals              Deccan Chargers
# 338                Delhi Capitals               Gujarat Titans
# 383           Sunrisers Hyderabad               Gujarat Titans
# ...

# %%
df[(df["toss_winner"]=="Rajasthan Royals") & (df["toss_decision"]=="bat")].shape[0]
# Out:
# 44

# %%
# Create column
df["D1"]=0

# %%
df
# Out:
#       match_number                        team1                        team2  \
# 0           336036             Rajasthan Royals               Mumbai Indians
# 1           335995              Kings XI Punjab             Delhi Daredevils
# 2          1254108  Royal Challengers Bangalore               Mumbai Indians
# 3           829761        Kolkata Knight Riders             Delhi Daredevils
# 4          1216521          Chennai Super Kings               Mumbai Indians
# ...            ...                          ...                          ...
# 1164        336017        Kolkata Knight Riders             Delhi Daredevils
# 1165        981007                Gujarat Lions               Mumbai Indians
# 1166        980931      Rising Pune Supergiants  Royal Challengers Bangalore
# 1167       1304095  Royal Challengers Bangalore          Chennai Super Kings
# 1168       1136568              Kings XI Punjab  Royal Challengers Bangalore
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_number     1169 non-null   int64
#  1   team1            1169 non-null   object
#  2   team2            1169 non-null   object
#  3   match_date       1169 non-null   object
#  4   toss_winner      1169 non-null   object
#  5   toss_decision    1169 non-null   object
#  6   result           1169 non-null   object
#  7   eliminator       15 non-null     object
#  8   winner           1146 non-null   object
#  9   player_of_match  1169 non-null   object
#  10  venue            1169 non-null   object
#  11  city             1118 non-null   object
#  12  team1_players    1169 non-null   object
#  13  team2_players    1169 non-null   object
#  14  D1               1169 non-null   int64
# dtypes: int64(2), object(13)
# memory usage: 137.1+ KB

# %%
df.isnull().sum()
# Out:
# match_number          0
# team1                 0
# team2                 0
# match_date            0
# toss_winner           0
# toss_decision         0
# result                0
# eliminator         1154
# winner               23
# player_of_match       0
# venue                 0
# city                 51
# team1_players         0
# team2_players         0
# D1                    0
# dtype: int64

# %%
import numpy as np
data={"dhruv":[100,200,0,np.nan],"dhoni":[100,np.nan,0,np.nan],
      "kohli":[np.nan,90,78,12],"a":[200,100,200,300]}

df=pd.DataFrame(data)
df
# Out:
#    dhruv  dhoni  kohli    a
# 0  100.0  100.0    NaN  200
# 1  200.0    NaN   90.0  100
# 2    0.0    0.0   78.0  200
# 3    NaN    NaN   12.0  300

# %%
df.dropna(thresh=3, axis = 1)
# Out:
#    dhruv  kohli    a
# 0  100.0    NaN  200
# 1  200.0   90.0  100
# 2    0.0   78.0  200
# 3    NaN   12.0  300

# %%
df.dropna(subset=["dhoni"])
# Out:
#    dhruv  dhoni  kohli    a
# 0  100.0  100.0    NaN  200
# 2    0.0    0.0   78.0  200

# %%
df
# Out:
#    dhruv  dhoni  kohli    a
# 0  100.0  100.0    NaN  200
# 1  200.0    NaN   90.0  100
# 2    0.0    0.0   78.0  200
# 3    NaN    NaN   12.0  300

# %%
df.dropna(subset=["dhoni"])
# Out:
#    dhruv  dhoni  kohli    a
# 0  100.0  100.0    NaN  200
# 2    0.0    0.0   78.0  200

# %%
df["dhoni"].fillna("dhoni")
# Out:
# 0    100.0
# 1    dhoni
# 2      0.0
# 3    dhoni
# Name: dhoni, dtype: object

# %%
df.fillna(100,inplace=True)
df
# Out:
#    dhruv  dhoni  kohli    a
# 0  100.0  100.0  100.0  200
# 1  200.0  100.0   90.0  100
# 2    0.0    0.0   78.0  200
# 3  100.0  100.0   12.0  300

# %%
df["dhoni"].sum()
# Out:
# np.float64(300.0)

# %%
df["dhoni"].mean()
# Out:
# np.float64(75.0)

# %%
df.drop([0,1],axis=0)
# Out:
#    dhruv  dhoni  kohli    a
# 2    0.0    0.0   78.0  200
# 3  100.0  100.0   12.0  300

# %%
df.drop("dhoni",axis=1)
# Out:
#    dhruv  kohli    a
# 0  100.0  100.0  200
# 1  200.0   90.0  100
# 2    0.0   78.0  200
# 3  100.0   12.0  300

# %%
df.drop_duplicates() 
# no duplicates values
# Out:
#    dhruv  dhoni  kohli    a
# 0  100.0  100.0  100.0  200
# 1  200.0  100.0   90.0  100
# 2    0.0    0.0   78.0  200
# 3  100.0  100.0   12.0  300

# %%
data={"name":["a","b","a"],"marks":[100,20,100]}
df=pd.DataFrame(data)
df
# Out:
#   name  marks
# 0    a    100
# 1    b     20
# 2    a    100

# %%
df.drop_duplicates(keep="last")
# by default keep="first"
# Out:
#   name  marks
# 1    b     20
# 2    a    100

# %%
df.sort_values(by="marks")
# Out:
#   name  marks
# 1    b     20
# 0    a    100
# 2    a    100
